# %%
# !pip install jsonpath_ng
# Out:
# Requirement already satisfied: jsonpath_ng in c:\users\eliel\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: ply in c:\users\eliel\anaconda3\lib\site-packages (from jsonpath_ng) (3.11)
# Requirement already satisfied: decorator in c:\users\eliel\anaconda3\lib\site-packages (from jsonpath_ng) (4.4.2)
# Requirement already satisfied: six in c:\users\eliel\anaconda3\lib\site-packages (from jsonpath_ng) (1.15.0)

# %%
import os
import csv
import json
import numpy as np
import pandas as pd
import sqlite3
import functools as ft
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from jsonpath_ng import parse
from enum import Enum
# %matplotlib inline

# %% [markdown]
# Data

# %%
with open("Sales by Store.csv", "r", encoding="utf-8-sig") as file:
    data = list(csv.DictReader(file))
    for item in data:
        item["transaction_id"] = str(item["transaction_id"])
data[:10]
# Out:
# [{'transaction_id': '1338',
#   'transaction_date': '42736',
#   'transaction_time': '0.295960648',
#   'store_city': 'New York',
#   'staff_id': '30',
#   'staff_Name': 'Amela Chadwick',
#   'customer_id': '5465',
#   'instore_yn': 'Y',
#   'order': '1',
#   'line_item_id': '1',
#   'product_id': '32',
#   'product': 'Ethiopia Rg',
#   'product_category': 'Coffee',
#   'quantity_sold': '2',
#   'unit_price': '3',
#   'promo_item_yn': 'N'},
#  {'transaction_id': '399',
#   'transaction_date': '42736',
#   'transaction_time': '0.29787037',
#   'store_city': 'New York',
#   'staff_id': '30',
#   'staff_Name': 'Amela Chadwick',
#   'customer_id': '5895',
#   'instore_yn': 'Y',
#   'order': '1',
#   'line_item_id': '1',
#   'product_id': '57',
#   'product': 'Spicy Eye Opener Chai Lg',
#   'product_category': 'Tea',
#   'quantity_sold': '2',
#   'unit_price': '3.1',
#   'promo_item_yn': 'N'},
#  {'transaction_id': '451',
#   'transaction_date': '42736',
#   'transaction_time': '0.301435185',
#   'store_city': 'New York',
#   'staff_id': '26',
#   'staff_Name': 'Joelle Christen',
#   'customer_id': '5412',
#   'instore_yn': 'N',
#   'order': '1',
#   'line_item_id': '1',
#   'product_id': '59',
#   'product': 'Dark chocolate Lg',
#   'product_category': 'Drinking Chocolate',
#   'quantity_sold': '2',
#   'unit_price': '4.5',
#   'promo_item_yn': 'N'},
#  {'transaction_id': '1170',
#   'transaction_date': '42736',
#   'transaction_time': '0.305833333',
#   'store_city': 'New York',
#   'staff_id': '12',
#   'staff_Name': 'Britanni Jorden',
#   'customer_id': '5676',
#   'instore_yn': 'Y',
#   'order': '1',
#   'line_item_id': '1',
#   'product_id': '22',
#   'product': 'Our Old Time Diner Blend Sm',
#   'product_category': 'Coffee',
#   'quantity_sold': '1',
#   'unit_price': '2',
#   'promo_item_yn': 'N'},
#  {'transaction_id': '248',
#   'transaction_date': '42736',
#   'transaction_time': '0.307418981',
#   'store_city': 'New York',
#   'staff_id': '30',
#   'staff_Name': 'Amela Chadwick',
#   'customer_id': '5479',
#   'instore_yn': 'N',
#   'order': '1',
#   'line_item_id': '1',
#   'product_id': '57',
#   'product': 'Spicy Eye Opener Chai Lg',
#   'product_category': 'Tea',
#   'quantity_sold': '2',
#   'unit_price': '3.1',
#   'promo_item_yn': 'N'},
#  {'transaction_id': '248',
#   'transaction_date': '42736',
#   'transaction_time': '0.307418981',
#   'store_city': 'New York',
#   'staff_id': '30',
#   'staff_Name': 'Amela Chadwick',
#   'customer_id': '5479',
#   'instore_yn': 'N',
#   'order': '1',
#   'line_item_id': '5',
#   'product_id': '77',
#   'product': 'Oatmeal Scone',
#   'product_category': 'Bakery',
#   'quantity_sold': '1',
#   'unit_price': '3',
#   'promo_item_yn': 'N'},
#  {'transaction_id': '335',
#   'transaction_date': '42736',
#   'transaction_time': '0.309594907',
#   'store_city': 'New York',
#   'staff_id': '12',
#   'staff_Name': 'Britanni Jorden',
#   'customer_id': '5543',
#   'instore_yn': 'Y',
#   'order': '1',
#   'line_item_id': '1',
#   'product_id': '22',
#   'product': 'Our Old Time Diner Blend Sm',
#   'product_category': 'Coffee',
#   'quantity_sold': '1',
#   'unit_price': '2',
#   'promo_item_yn': 'N'},
#  {'transaction_id': '2147',
#   'transaction_date': '42736',
#   'transaction_time': '0.314976852',
#   'store_city': 'New York',
#   'staff_id': '26',
#   'staff_Name': 'Joelle Christen',
#   'customer_id': '5195',
#   'instore_yn': 'N',
#   'order': '1',
#   'line_item_id': '1',
#   'product_id': '28',
#   'product': 'Columbian Medium Roast Sm',
#   'product_category': 'Coffee',
#   'quantity_sold': '2',
#   'unit_price': '2',
#   'promo_item_yn': 'N'},
#  {'transaction_id': '1911',
#   'transaction_date': '42736',
#   'transaction_time': '0.318900463',
#   'store_city': 'New York',
#   'staff_id': '12',
#   'staff_Name': 'Britanni Jorden',
#   'customer_id': '5231',
#   'instore_yn': 'Y',
#   'order': '1',
#   'line_item_id': '1',
#   'product_id': '39',
#   'product': 'Latte Rg',
#   'product_category': 'Coffee',
#   'quantity_sold': '1',
#   'unit_price': '4.25',
#   'promo_item_yn': 'N'},
#  {'transaction_id': '2399',
#   'transaction_date': '42736',
#   'transaction_time': '0.319143519',
#   'store_city': 'New York',
#   'staff_id': '30',
#   'staff_Name': 'Amela Chadwick',
#   'customer_id': '5489',
#   'instore_yn': 'Y',
#   'order': '1',
#   'line_item_id': '1',
#   'product_id': '58',
#   'product': 'Dark chocolate Rg',
#   'product_category': 'Drinking Chocolate',
#   'quantity_sold': '2',
#   'unit_price': '3.5',
#   'promo_item_yn': 'N'}]

# %% [markdown]
# Abstract Base Calss (ABC) for mutual methods

# %%
class Interface(ABC):

    @abstractmethod
    def get_data_by_field(self, field_name):
        """Fetch the data by given feild name """

    @abstractmethod
    def get_data_by_id(self, id):
        """Fetch the data by given ID  """

    @abstractmethod
    def get(self):
        """Fetch all data """

# %% [markdown]
# Transform Operations

# %%
class TransformMask(Enum):
    # add here any masks you want
    CLEAN_STRING = ".strip().lower()"
    CAPITAL_LETTER = ".strip().lower().title()"
    CLEAN_NUM = ""

# %% [markdown]
# Database Class - Define Common Properties for Source, Target, Mapping

# %%
class Database:
    def __init__(self):
        self.db = {
            "source": [],
            "destination": [],
            "transform": [],
            "mapping": []
        }
        self.add_source(1, "transaction_id", "str")
        self.add_destination(1, "Transaction_Id", "int", "Fact")
        self.add_transform(1, "CLEAN_NUM")
        self.add_mapping(1, 1, 1, 1, "Fact")

        self.add_source(2, "transaction_date", "str")
        self.add_destination(2, "Transaction_Date", "str", "Fact")
        self.add_transform(2, "CLEAN_STRING")
        self.add_mapping(2, 2, 2, 2, "Fact")

        self.add_source(3, "store_city", "str")
        self.add_destination(3, "Store_City", "str", "Fact")
        self.add_transform(3, "CAPITAL_LETTER")
        self.add_mapping(3, 3, 3, 3, "Fact")

        self.add_source(4, "staff_id", "str")
        self.add_destination(4, "Staff_Id", "int", "Fact")
        self.add_transform(1, "CLEAN_NUM")
        self.add_mapping(4, 4, 4, 1, "Fact")

        self.add_destination(5, "Staff_Id", "int", "Dim_Staff")
        self.add_transform(1, "CLEAN_NUM")
        self.add_mapping(5, 4, 5, 1, "Dim_Staff")

        self.add_source(5, "staff_Name", "str")
        self.add_destination(6, "Staff_Name", "str", "Dim_Staff")
        self.add_transform(3, "CAPITAL_LETTER")
        self.add_mapping(6, 5, 6, 3, "Dim_Staff")

        self.add_source(6, "customer_id", "str")
        self.add_destination(7, "Customer_Id", "int", "Fact")
        self.add_transform(1, "CLEAN_NUM")
        self.add_mapping(7, 6, 7, 1, "Fact")

        self.add_source(7, "product_id", "str")
        self.add_destination(8, "Product_Id", "int", "Fact")
        self.add_transform(1, "CLEAN_NUM")
        self.add_mapping(8, 7, 8, 1, "Fact")

        self.add_destination(9, "Product_Id", "int", "Dim_Product")
        self.add_transform(1, "CLEAN_NUM")
        self.add_mapping(9, 7, 9, 1, "Dim_Product")

        self.add_source(8, "product", "str")
        self.add_destination(10, "Product", "str", "Dim_Product")
        self.add_transform(3, "CAPITAL_LETTER")
        self.add_mapping(10, 8, 10, 3, "Dim_Product")

        self.add_source(9, "product_category", "str")
        self.add_destination(11, "Product_Category", "str", "Dim_Product")
        self.add_transform(3, "CAPITAL_LETTER")
        self.add_mapping(11, 9, 11, 3, "Dim_Product")

        self.add_source(10, "quantity_sold", "str")
        self.add_destination(12, "Quantity", "int", "Fact")
        self.add_transform(1, "CLEAN_NUM")
        self.add_mapping(12, 10, 12, 1, "Fact")

        self.add_source(11, "unit_price", "str")
        self.add_destination(13, "Unit_Price", "float", "Fact")
        self.add_transform(1, "CLEAN_NUM")
        self.add_mapping(13, 11, 13, 1, "Fact")


    def add_source(self, id, field, typ):
            self.db["source"].append({
                "id": id,
                "source_field_name": field,
                "source_field_mapping": field,
                "source_field_type": typ,
                "is_required": True,
            })

    def add_destination(self, id, field, typ, table):
        self.db["destination"].append({
            "id": id,
            "destination_field_name": field,
            "destination_field_mapping": field,
            "destination_field_type": typ,
            "default_value": "0",
            "destination_table": table,
        })

    def add_transform(self, id, mask):
        self.db["transform"].append({
            "id": id,
            "transform_mask": mask,
        })

    def add_mapping(self, id, source, dest, transform,table):
      self.db["mapping"].append({
          "id": id,
          "mapping_source": source,
          "mapping_destination": dest,
          "mapping_transform": transform,
          "destination_table": table,
        })


    @property
    def get_data_source_target_mapping(self):
      return self.db

# %% [markdown]
# Source Class

# %%
class Source(Interface, Database):
    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("source")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id") == self.id:
                return x
        return None

# %% [markdown]
# Target Class

# %%
class Target(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("destination")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# Transform Class

# %%
class Transform(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    # should be implemented - inherited from Interface
    def get_data_by_field(self, field_name):
        data = self.get
        for item in data:
            for key, value in item.items():
                if key == field_name:
                    return item
        return None

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("transform", [])

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

# %% [markdown]
# Mapping Class

# %%
class Mappings(Interface, Database):

    def __init__(self):
        Database.__init__(self)

    @property
    def get(self):
        return self.get_data_source_target_mapping.get("mapping")

    def get_data_by_id(self, id):
        self.id = id
        data = self.get
        for x in data:
            if x.get("id").__str__() == self.id.__str__():
                return x
        return None

    def get_data_by_field(self, field_name):
        return None

# %% [markdown]
# Format Class - JSON

# %%
class JsonQuery:
    def __init__(self, json_path, json_data):
        self.json_path = json_path
        self.json_data = json_data

    def get(self):
        jsonpath_expression = parse(self.json_path)
        match = jsonpath_expression.find(self.json_data)
        source_data_value = match[0].value
        return source_data_value

# %% [markdown]
# Combine it All - STTM

# %%
class STTM:
    def __init__(self, input_json):
        self.input_json = input_json
        self.mapping_instance = Mappings()
        self.source_instance = Source()
        self.destination_instance = Target()
        self.transform_instance = Transform()
        self.look_up_mask = {i.name: i.value for i in TransformMask}
        self.json_data_transformed = {}
        self.to_table = {}

    def _get_mapping_data(self):
        return self.mapping_instance.get

    def _get_mapping_source_data(self):
        return self.source_instance.get

    def get_transformed_data(self):

        for mappings in self._get_mapping_data():

            """fetch the source mapping """
            mapping_source_id = mappings.get("mapping_source")
            mapping_destination_id = mappings.get("mapping_destination")
            mapping_transform_id = mappings.get("mapping_transform")
            mapping_table = mappings.get("destination_table")


            mapping_source_data = self.source_instance.get_data_by_id(id=mapping_source_id)
            transform_data = self.transform_instance.get_data_by_id(id=mapping_transform_id)

            """Fetch Source  field Name"""
            source_field_name = mapping_source_data.get("source_field_name")

            """if field given is not present incoming json """
            if source_field_name not in self.input_json.keys():
                if mapping_source_data.get("is_required"):
                    raise Exception(
                        "Alert ! Field {} is not present in JSON please FIX mappings ".format(source_field_name))
                else:
                    pass

            else:
                source_data_value = JsonQuery(
                    json_path=mapping_source_data.get("source_field_mapping"),
                    json_data=self.input_json
                ).get()

                """check the data type for source if matches with what we have """
                if mapping_source_data.get("source_field_type") != type(source_data_value).__name__:
                    if source_data_value is not None:
                        _message = (
                            "Alert ! Source Field :{} Datatype has changed from {} to {} ".format(source_field_name,
                                                                                                  mapping_source_data.get(
                                                                                                      "source_field_type"),
                                                                                                  type(
                                                                                                      source_data_value).__name__))
                        print(_message)
                        raise Exception(_message)

                """Query and fetch the Destination | target """
                destination_mappings_json_object = self.destination_instance.get_data_by_id(
                    id=mappings.get("mapping_destination"))

                destination_field_name = destination_mappings_json_object.get("destination_field_name")
                destination_field_type = destination_mappings_json_object.get("destination_field_type")

                # check if the dictionary is empty
                if destination_field_name in self.to_table:
                  self.to_table[destination_field_name].append(mapping_table)
                else:
                  self.to_table[destination_field_name] = [mapping_table]


                dtypes = [str, float, list, int, set, dict]

                for dtype in dtypes:

                    """Datatype Conversion """
                    if destination_field_type == str(dtype.__name__):

                        """is source is none insert default value"""
                        if source_data_value is None:
                            self.json_data_transformed[destination_field_name] = dtype.__call__(
                                destination_mappings_json_object.get("default_value")
                            )

                        else:
                            """check if you have items to transform"""
                            if transform_data is not None:
                                """ check for invalid mask name """
                                if transform_data.get("transform_mask") not in list(self.look_up_mask.keys()):
                                    raise Exception(
                                        f"Specified Transform {transform_data.get('transform_mask')} is not available please select from following Options :{list(self.look_up_mask.keys())}")
                                else:
                                    mask_apply = self.look_up_mask.get(transform_data.get("transform_mask"))
                                    converted_dtype = dtype.__call__(source_data_value)
                                    mask = f'converted_dtype{mask_apply}'
                                    curated_value = eval(mask)
                                    self.json_data_transformed[destination_field_name] = curated_value

                            else:
                                self.json_data_transformed[destination_field_name] = dtype.__call__(source_data_value)

        return self.json_data_transformed, self.to_table

# %%
transformed_data = []
for item in data:
    helper = STTM(input_json=item)
    response, mapping = helper.get_transformed_data()
    transformed_data.append(response)
    print(response)
print(mapping)
# Out:
# {'Transaction_Id': 1338, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5465, 'Product_Id': 32, 'Product': 'Ethiopia Rg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 399, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5895, 'Product_Id': 57, 'Product': 'Spicy Eye Opener Chai Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.1}
# {'Transaction_Id': 451, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5412, 'Product_Id': 59, 'Product': 'Dark Chocolate Lg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 2, 'Unit_Price': 4.5}
# {'Transaction_Id': 1170, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5676, 'Product_Id': 22, 'Product': 'Our Old Time Diner Blend Sm', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 2.0}
# {'Transaction_Id': 248, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5479, 'Product_Id': 57, 'Product': 'Spicy Eye Opener Chai Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.1}
# {'Transaction_Id': 248, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5479, 'Product_Id': 77, 'Product': 'Oatmeal Scone', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 335, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5543, 'Product_Id': 22, 'Product': 'Our Old Time Diner Blend Sm', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 2.0}
# {'Transaction_Id': 2147, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5195, 'Product_Id': 28, 'Product': 'Columbian Medium Roast Sm', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 2.0}
# {'Transaction_Id': 1911, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5231, 'Product_Id': 39, 'Product': 'Latte Rg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 4.25}
# {'Transaction_Id': 2399, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5489, 'Product_Id': 58, 'Product': 'Dark Chocolate Rg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 2, 'Unit_Price': 3.5}
# {'Transaction_Id': 534, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5373, 'Product_Id': 56, 'Product': 'Spicy Eye Opener Chai Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.55}
# {'Transaction_Id': 1295, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5162, 'Product_Id': 33, 'Product': 'Ethiopia Lg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.5}
# {'Transaction_Id': 2475, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5394, 'Product_Id': 51, 'Product': 'Earl Grey Lg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 1483, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5491, 'Product_Id': 57, 'Product': 'Spicy Eye Opener Chai Lg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 3.1}
# {'Transaction_Id': 443, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5180, 'Product_Id': 87, 'Product': 'Ouro Brasileiro Shot', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 1074, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5477, 'Product_Id': 47, 'Product': 'Serenity Green Tea Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 1074, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5477, 'Product_Id': 79, 'Product': 'Jumbo Savory Scone', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.75}
# {'Transaction_Id': 1291, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8480, 'Product_Id': 42, 'Product': 'Lemon Grass Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 1509, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8392, 'Product_Id': 59, 'Product': 'Dark Chocolate Lg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 2, 'Unit_Price': 4.5}
# {'Transaction_Id': 41, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8293, 'Product_Id': 61, 'Product': 'Sustainably Grown Organic Lg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 1, 'Unit_Price': 4.75}
# {'Transaction_Id': 2806, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8483, 'Product_Id': 33, 'Product': 'Ethiopia Lg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.5}
# {'Transaction_Id': 1787, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5290, 'Product_Id': 56, 'Product': 'Spicy Eye Opener Chai Rg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 2.55}
# {'Transaction_Id': 1787, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5290, 'Product_Id': 69, 'Product': 'Hazelnut Biscotti', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.25}
# {'Transaction_Id': 2257, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8023, 'Product_Id': 56, 'Product': 'Spicy Eye Opener Chai Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.55}
# {'Transaction_Id': 737, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8003, 'Product_Id': 40, 'Product': 'Cappuccino', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.75}
# {'Transaction_Id': 2287, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5691, 'Product_Id': 43, 'Product': 'Lemon Grass Lg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 2287, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5691, 'Product_Id': 76, 'Product': 'Chocolate Chip Biscotti', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.5}
# {'Transaction_Id': 170, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5401, 'Product_Id': 45, 'Product': 'Peppermint Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 170, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5401, 'Product_Id': 71, 'Product': 'Chocolate Croissant', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.75}
# {'Transaction_Id': 699, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8278, 'Product_Id': 40, 'Product': 'Cappuccino', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.75}
# {'Transaction_Id': 2386, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8400, 'Product_Id': 38, 'Product': 'Latte', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.75}
# {'Transaction_Id': 14, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5924, 'Product_Id': 26, 'Product': 'Brazilian Rg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 1496, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5721, 'Product_Id': 27, 'Product': 'Brazilian Lg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.5}
# {'Transaction_Id': 2319, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5896, 'Product_Id': 29, 'Product': 'Columbian Medium Roast Rg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 2.5}
# {'Transaction_Id': 6, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8398, 'Product_Id': 54, 'Product': 'Morning Sunrise Chai Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 304, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5317, 'Product_Id': 26, 'Product': 'Brazilian Rg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 64, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5391, 'Product_Id': 55, 'Product': 'Morning Sunrise Chai Lg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 4.0}
# {'Transaction_Id': 2476, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8164, 'Product_Id': 40, 'Product': 'Cappuccino', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.75}
# {'Transaction_Id': 1504, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 15, 'Staff_Name': 'Remedios Mari', 'Customer_Id': 8007, 'Product_Id': 45, 'Product': 'Peppermint Lg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 2719, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8348, 'Product_Id': 45, 'Product': 'Peppermint Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 133, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8176, 'Product_Id': 24, 'Product': 'Our Old Time Diner Blend Lg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 2313, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5445, 'Product_Id': 60, 'Product': 'Sustainably Grown Organic Rg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 2, 'Unit_Price': 3.75}
# {'Transaction_Id': 2313, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5445, 'Product_Id': 78, 'Product': 'Scottish Cream Scone', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 4.5}
# {'Transaction_Id': 283, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5418, 'Product_Id': 56, 'Product': 'Spicy Eye Opener Chai Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.55}
# {'Transaction_Id': 283, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5418, 'Product_Id': 77, 'Product': 'Oatmeal Scone', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 1629, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5602, 'Product_Id': 44, 'Product': 'Peppermint Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 82, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5806, 'Product_Id': 56, 'Product': 'Spicy Eye Opener Chai Rg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 2.55}
# {'Transaction_Id': 2317, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5061, 'Product_Id': 48, 'Product': 'English Breakfast Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 177, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8118, 'Product_Id': 23, 'Product': 'Our Old Time Diner Blend Rg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 2397, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8448, 'Product_Id': 46, 'Product': 'Serenity Green Tea Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 577, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8350, 'Product_Id': 32, 'Product': 'Ethiopia Rg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 1460, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5538, 'Product_Id': 47, 'Product': 'Serenity Green Tea Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 2007, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5902, 'Product_Id': 43, 'Product': 'Lemon Grass Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 2123, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5827, 'Product_Id': 25, 'Product': 'Brazilian Sm', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 2.2}
# {'Transaction_Id': 1410, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 15, 'Staff_Name': 'Remedios Mari', 'Customer_Id': 8197, 'Product_Id': 59, 'Product': 'Dark Chocolate Lg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 1, 'Unit_Price': 4.5}
# {'Transaction_Id': 1919, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5539, 'Product_Id': 38, 'Product': 'Latte', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.75}
# {'Transaction_Id': 514, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 15, 'Staff_Name': 'Remedios Mari', 'Customer_Id': 8436, 'Product_Id': 45, 'Product': 'Peppermint Lg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 2374, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5141, 'Product_Id': 34, 'Product': 'Jamaican Coffee River Sm', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 2.45}
# {'Transaction_Id': 238, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8267, 'Product_Id': 36, 'Product': 'Jamaican Coffee River Lg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.75}
# {'Transaction_Id': 238, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8267, 'Product_Id': 74, 'Product': 'Ginger Biscotti', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.5}
# {'Transaction_Id': 1732, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 15, 'Staff_Name': 'Remedios Mari', 'Customer_Id': 8146, 'Product_Id': 53, 'Product': 'Traditional Blend Chai Lg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 2440, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8183, 'Product_Id': 41, 'Product': 'Cappuccino Lg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 4.25}
# {'Transaction_Id': 1736, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5439, 'Product_Id': 41, 'Product': 'Cappuccino Lg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 4.25}
# {'Transaction_Id': 988, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5138, 'Product_Id': 45, 'Product': 'Peppermint Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 988, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5138, 'Product_Id': 79, 'Product': 'Jumbo Savory Scone', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.75}
# {'Transaction_Id': 1195, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5878, 'Product_Id': 54, 'Product': 'Morning Sunrise Chai Rg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 2.5}
# {'Transaction_Id': 2099, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5158, 'Product_Id': 24, 'Product': 'Our Old Time Diner Blend Lg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 2516, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5136, 'Product_Id': 37, 'Product': 'Espresso Shot', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 2777, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8467, 'Product_Id': 40, 'Product': 'Cappuccino', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.75}
# {'Transaction_Id': 1841, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5415, 'Product_Id': 37, 'Product': 'Espresso Shot', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 1841, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5415, 'Product_Id': 69, 'Product': 'Hazelnut Biscotti', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.25}
# {'Transaction_Id': 1674, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5285, 'Product_Id': 50, 'Product': 'Earl Grey Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 853, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8075, 'Product_Id': 47, 'Product': 'Serenity Green Tea Lg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 723, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8310, 'Product_Id': 40, 'Product': 'Cappuccino', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.75}
# {'Transaction_Id': 723, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8310, 'Product_Id': 72, 'Product': 'Ginger Scone', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.25}
# {'Transaction_Id': 1627, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 15, 'Staff_Name': 'Remedios Mari', 'Customer_Id': 8159, 'Product_Id': 35, 'Product': 'Jamaican Coffee River Rg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.1}
# {'Transaction_Id': 2268, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5610, 'Product_Id': 23, 'Product': 'Our Old Time Diner Blend Rg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 2087, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5561, 'Product_Id': 43, 'Product': 'Lemon Grass Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 59, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8471, 'Product_Id': 22, 'Product': 'Our Old Time Diner Blend Sm', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 2.0}
# {'Transaction_Id': 1998, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8219, 'Product_Id': 32, 'Product': 'Ethiopia Rg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 1416, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8443, 'Product_Id': 36, 'Product': 'Jamaican Coffee River Lg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.75}
# {'Transaction_Id': 1688, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5071, 'Product_Id': 26, 'Product': 'Brazilian Rg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.0}
# {'Transaction_Id': 1688, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5071, 'Product_Id': 71, 'Product': 'Chocolate Croissant', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.75}
# {'Transaction_Id': 2394, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5916, 'Product_Id': 32, 'Product': 'Ethiopia Rg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 442, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8007, 'Product_Id': 54, 'Product': 'Morning Sunrise Chai Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 2211, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 15, 'Staff_Name': 'Remedios Mari', 'Customer_Id': 8445, 'Product_Id': 41, 'Product': 'Cappuccino Lg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 4.25}
# {'Transaction_Id': 1752, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5619, 'Product_Id': 25, 'Product': 'Brazilian Sm', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 2.2}
# {'Transaction_Id': 1856, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5419, 'Product_Id': 23, 'Product': 'Our Old Time Diner Blend Rg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 2.5}
# {'Transaction_Id': 1544, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8012, 'Product_Id': 54, 'Product': 'Morning Sunrise Chai Rg', 'Product_Category': 'Tea', 'Quantity': 1, 'Unit_Price': 2.5}
# {'Transaction_Id': 45, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 42, 'Staff_Name': 'Kylie Candace', 'Customer_Id': 8445, 'Product_Id': 56, 'Product': 'Spicy Eye Opener Chai Rg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 2.55}
# {'Transaction_Id': 1211, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5073, 'Product_Id': 58, 'Product': 'Dark Chocolate Rg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 2, 'Unit_Price': 3.5}
# {'Transaction_Id': 1211, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 26, 'Staff_Name': 'Joelle Christen', 'Customer_Id': 5073, 'Product_Id': 74, 'Product': 'Ginger Biscotti', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.5}
# {'Transaction_Id': 1230, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 15, 'Staff_Name': 'Remedios Mari', 'Customer_Id': 8458, 'Product_Id': 47, 'Product': 'Serenity Green Tea Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 753, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5384, 'Product_Id': 35, 'Product': 'Jamaican Coffee River Rg', 'Product_Category': 'Coffee', 'Quantity': 1, 'Unit_Price': 3.1}
# {'Transaction_Id': 753, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5384, 'Product_Id': 70, 'Product': 'Cranberry Scone', 'Product_Category': 'Bakery', 'Quantity': 1, 'Unit_Price': 3.25}
# {'Transaction_Id': 1872, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 45, 'Staff_Name': 'Pandora Neville', 'Customer_Id': 8059, 'Product_Id': 60, 'Product': 'Sustainably Grown Organic Rg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 1, 'Unit_Price': 3.75}
# {'Transaction_Id': 842, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 12, 'Staff_Name': 'Britanni Jorden', 'Customer_Id': 5392, 'Product_Id': 59, 'Product': 'Dark Chocolate Lg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 1, 'Unit_Price': 4.5}
# {'Transaction_Id': 550, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5531, 'Product_Id': 36, 'Product': 'Jamaican Coffee River Lg', 'Product_Category': 'Coffee', 'Quantity': 2, 'Unit_Price': 3.75}
# {'Transaction_Id': 589, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 15, 'Staff_Name': 'Remedios Mari', 'Customer_Id': 8036, 'Product_Id': 51, 'Product': 'Earl Grey Lg', 'Product_Category': 'Tea', 'Quantity': 2, 'Unit_Price': 3.0}
# {'Transaction_Id': 1708, 'Transaction_Date': '42736', 'Store_City': 'New York', 'Staff_Id': 30, 'Staff_Name': 'Amela Chadwick', 'Customer_Id': 5394, 'Product_Id': 61, 'Product': 'Sustainably Grown Organic Lg', 'Product_Category': 'Drinking Chocolate', 'Quantity': 2, 'Unit_Price': 4.75}
# {'Transaction_Id': ['Fact'], 'Transaction_Date': ['Fact'], 'Store_City': ['Fact'], 'Staff_Id': ['Fact', 'Dim_Staff'], 'Staff_Name': ['Dim_Staff'], 'Customer_Id': ['Fact'], 'Product_Id': ['Fact', 'Dim_Product'], 'Product': ['Dim_Product'], 'Product_Category': ['Dim_Product'], 'Quantity': ['Fact'], 'Unit_Price': ['Fact']}

# %%
pd.DataFrame(transformed_data)
# Out:
#     Transaction_Id Transaction_Date Store_City  Staff_Id       Staff_Name  \
# 0             1338            42736   New York        30   Amela Chadwick
# 1              399            42736   New York        30   Amela Chadwick
# 2              451            42736   New York        26  Joelle Christen
# 3             1170            42736   New York        12  Britanni Jorden
# 4              248            42736   New York        30   Amela Chadwick
# ..             ...              ...        ...       ...              ...
# 95            1872            42736   New York        45  Pandora Neville
# 96             842            42736   New York        12  Britanni Jorden
# 97             550            42736   New York        30   Amela Chadwick
# 98             589            42736   New York        15    Remedios Mari
# 99            1708            42736   New York        30   Amela Chadwick
#
#     Customer_Id  Product_Id                       Product    Product_Category  \
# 0          5465          32                   Ethiopia Rg              Coffee
# 1          5895          57      Spicy Eye Opener Chai Lg                 Tea
# 2          5412          59             Dark Chocolate Lg  Drinking Chocolate
# 3          5676          22   Our Old Time Diner Blend Sm              Coffee
# 4          5479          57      Spicy Eye Opener Chai Lg                 Tea
# ..          ...         ...                           ...                 ...
# 95         8059          60  Sustainably Grown Organic Rg  Drinking Chocolate
# 96         5392          59             Dark Chocolate Lg  Drinking Chocolate
# 97         5531          36      Jamaican Coffee River Lg              Coffee
# 98         8036          51                  Earl Grey Lg                 Tea
# 99         5394          61  Sustainably Grown Organic Lg  Drinking Chocolate
#
#     Quantity  Unit_Price
# 0          2        3.00
# 1          2        3.10
# 2          2        4.50
# 3          1        2.00
# 4          2        3.10
# ..       ...         ...
# 95         1        3.75
# 96         1        4.50
# 97         2        3.75
# 98         2        3.00
# 99         2        4.75
#
# [100 rows x 11 columns]

# %%
mapping
# Out:
# {'Transaction_Id': ['Fact'],
#  'Transaction_Date': ['Fact'],
#  'Store_City': ['Fact'],
#  'Staff_Id': ['Fact', 'Dim_Staff'],
#  'Staff_Name': ['Dim_Staff'],
#  'Customer_Id': ['Fact'],
#  'Product_Id': ['Fact', 'Dim_Product'],
#  'Product': ['Dim_Product'],
#  'Product_Category': ['Dim_Product'],
#  'Quantity': ['Fact'],
#  'Unit_Price': ['Fact']}

# %% [markdown]
# Splitting to tables and download as csv

# %%
fact_table = pd.DataFrame(transformed_data)
fact_columns = [col for col, labels in mapping.items() if 'Fact' in labels]
fact = pd.DataFrame(fact_table[fact_columns])
fact
# Out:
#     Transaction_Id Transaction_Date Store_City  Staff_Id  Customer_Id  \
# 0             1338            42736   New York        30         5465
# 1              399            42736   New York        30         5895
# 2              451            42736   New York        26         5412
# 3             1170            42736   New York        12         5676
# 4              248            42736   New York        30         5479
# ..             ...              ...        ...       ...          ...
# 95            1872            42736   New York        45         8059
# 96             842            42736   New York        12         5392
# 97             550            42736   New York        30         5531
# 98             589            42736   New York        15         8036
# 99            1708            42736   New York        30         5394
#
#     Product_Id  Quantity  Unit_Price
# 0           32         2        3.00
# 1           57         2        3.10
# 2           59         2        4.50
# 3           22         1        2.00
# 4           57         2        3.10
# ..         ...       ...         ...
# 95          60         1        3.75
# 96          59         1        4.50
# 97          36         2        3.75
# 98          51         2        3.00
# 99          61         2        4.75
#
# [100 rows x 8 columns]

# %%
fact.to_csv('Fact.csv', index=False)

# %%
staff = pd.DataFrame(transformed_data)
staff_columns = [col for col, labels in mapping.items() if 'Dim_Staff' in labels]
Dim_Staff = pd.DataFrame(staff[staff_columns])
Dim_Staff = Dim_Staff.drop_duplicates()
Dim_Staff
# Out:
#     Staff_Id       Staff_Name
# 0         30   Amela Chadwick
# 2         26  Joelle Christen
# 3         12  Britanni Jorden
# 17        45  Pandora Neville
# 20        42    Kylie Candace
# 38        15    Remedios Mari

# %%
Dim_Staff.to_csv('Dim_Staff.csv', index=False)

# %%
product = pd.DataFrame(transformed_data)
product_columns = [col for col, labels in mapping.items() if 'Dim_Product' in labels]
Dim_Product = pd.DataFrame(product[product_columns])
Dim_Product = Dim_Product.drop_duplicates()
Dim_Product
# Out:
#     Product_Id                       Product    Product_Category
# 0           32                   Ethiopia Rg              Coffee
# 1           57      Spicy Eye Opener Chai Lg                 Tea
# 2           59             Dark Chocolate Lg  Drinking Chocolate
# 3           22   Our Old Time Diner Blend Sm              Coffee
# 5           77                 Oatmeal Scone              Bakery
# 7           28     Columbian Medium Roast Sm              Coffee
# 8           39                      Latte Rg              Coffee
# 9           58             Dark Chocolate Rg  Drinking Chocolate
# 10          56      Spicy Eye Opener Chai Rg                 Tea
# 11          33                   Ethiopia Lg              Coffee
# 12          51                  Earl Grey Lg                 Tea
# 14          87          Ouro Brasileiro Shot              Coffee
# 15          47         Serenity Green Tea Lg                 Tea
# 16          79            Jumbo Savory Scone              Bakery
# 17          42                Lemon Grass Rg                 Tea
# 19          61  Sustainably Grown Organic Lg  Drinking Chocolate
# 22          69             Hazelnut Biscotti              Bakery
# 24          40                    Cappuccino              Coffee
# 25          43                Lemon Grass Lg                 Tea
# 26          76       Chocolate Chip Biscotti              Bakery
# 27          45                 Peppermint Lg                 Tea
# 28          71           Chocolate Croissant              Bakery
# 30          38                         Latte              Coffee
# 31          26                  Brazilian Rg              Coffee
# 32          27                  Brazilian Lg              Coffee
# 33          29     Columbian Medium Roast Rg              Coffee
# 34          54       Morning Sunrise Chai Rg                 Tea
# 36          55       Morning Sunrise Chai Lg                 Tea
# 40          24   Our Old Time Diner Blend Lg              Coffee
# 41          60  Sustainably Grown Organic Rg  Drinking Chocolate
# 42          78          Scottish Cream Scone              Bakery
# 45          44                 Peppermint Rg                 Tea
# 47          48          English Breakfast Rg                 Tea
# 48          23   Our Old Time Diner Blend Rg              Coffee
# 49          46         Serenity Green Tea Rg                 Tea
# 53          25                  Brazilian Sm              Coffee
# 57          34      Jamaican Coffee River Sm              Coffee
# 58          36      Jamaican Coffee River Lg              Coffee
# 59          74               Ginger Biscotti              Bakery
# 60          53     Traditional Blend Chai Lg                 Tea
# 61          41                 Cappuccino Lg              Coffee
# 67          37                 Espresso Shot              Coffee
# 71          50                  Earl Grey Rg                 Tea
# 74          72                  Ginger Scone              Bakery
# 75          35      Jamaican Coffee River Rg              Coffee
# 94          70               Cranberry Scone              Bakery

# %%
Dim_Product.to_csv('Dim_Product.csv', index=False)
